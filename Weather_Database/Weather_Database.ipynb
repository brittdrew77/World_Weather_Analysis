# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#Import citipy
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in lat_lngs:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library 
import time

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | cape town
# Processing Record 3 of Set 1 | vaini
# Processing Record 4 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 5 of Set 1 | lamu
# Processing Record 6 of Set 1 | maumere
# Processing Record 7 of Set 1 | chumikan
# Processing Record 8 of Set 1 | port-cartier
# Processing Record 9 of Set 1 | bluff
# Processing Record 10 of Set 1 | ardakan
# Processing Record 11 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 12 of Set 1 | castro
# Processing Record 13 of Set 1 | port hawkesbury
# Processing Record 14 of Set 1 | new norfolk
# Processing Record 15 of Set 1 | hualmay
# Processing Record 16 of Set 1 | richards bay
# Processing Record 17 of Set 1 | bengkulu
# Processing Record 18 of Set 1 | namatanai
# Processing Record 19 of Set 1 | mataura
# Processing Record 20 of Set 1 | khonsa
# Processing Record 21 of Set 1 | tasiilaq
# Processing Record 22 of Set 1 | puerto escondido
# Processing Record 23 of Set 1 | amapa
# Processing Record 24 of Set 1 | hermanus
# Processing Record 25 of Set 1 | kabo
# Processing Record 26 of Set 1 | port alfred
# Processing Record 27 of Set 1 | bredasdorp
# Processing Record 28 of Set 1 | kapaa
# Processing Record 29 of Set 1 | georgetown
# Processing Record 30 of Set 1 | puntarenas
# Processing Record 31 of Set 1 | lindas
# Processing Record 32 of Set 1 | kavieng
# Processing Record 33 of Set 1 | lavrentiya
# Processing Record 34 of Set 1 | manadhoo
# Processing Record 35 of Set 1 | torbay
# Processing Record 36 of Set 1 | east london
# Processing Record 37 of Set 1 | ushuaia
# Processing Record 38 of Set 1 | rikitea
# Processing Record 39 of Set 1 | staryy nadym
# Processing Record 40 of Set 1 | geraldton
# Processing Record 41 of Set 1 | hilo
# Processing Record 42 of Set 1 | cidreira
# Processing Record 43 of Set 1 | luanda
# Processing Record 44 of Set 1 | vostok
# Processing Record 45 of Set 1 | sao lourenco do sul
# Processing Record 46 of Set 1 | satitoa
# City not found. Skipping...
# Processing Record 47 of Set 1 | kaitangata
# Processing Record 48 of Set 1 | arraial do cabo
# Processing Record 49 of Set 1 | oltu
# Processing Record 50 of Set 1 | salta
# Processing Record 1 of Set 2 | yellowknife
# Processing Record 2 of Set 2 | thunder bay
# Processing Record 3 of Set 2 | jamestown
# Processing Record 4 of Set 2 | hithadhoo
# Processing Record 5 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 2 | kromy
# Processing Record 7 of Set 2 | punta arenas
# Processing Record 8 of Set 2 | khatanga
# Processing Record 9 of Set 2 | namibe
# Processing Record 10 of Set 2 | hobyo
# Processing Record 11 of Set 2 | thompson
# Processing Record 12 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 2 | maceio
# Processing Record 14 of Set 2 | kieta
# Processing Record 15 of Set 2 | dunedin
# Processing Record 16 of Set 2 | chuy
# Processing Record 17 of Set 2 | ancud
# Processing Record 18 of Set 2 | victoria
# Processing Record 19 of Set 2 | moberly
# Processing Record 20 of Set 2 | tuatapere
# Processing Record 21 of Set 2 | taoudenni
# Processing Record 22 of Set 2 | ahipara
# Processing Record 23 of Set 2 | portobelo
# Processing Record 24 of Set 2 | clyde river
# Processing Record 25 of Set 2 | aksarka
# Processing Record 26 of Set 2 | aykhal
# Processing Record 27 of Set 2 | iqaluit
# Processing Record 28 of Set 2 | asau
# Processing Record 29 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of Set 2 | airai
# Processing Record 31 of Set 2 | elizabethtown
# Processing Record 32 of Set 2 | peleduy
# Processing Record 33 of Set 2 | bandar-e lengeh
# Processing Record 34 of Set 2 | sitka
# Processing Record 35 of Set 2 | mwene-ditu
# Processing Record 36 of Set 2 | biak
# Processing Record 37 of Set 2 | hobart
# Processing Record 38 of Set 2 | martapura
# Processing Record 39 of Set 2 | maniitsoq
# Processing Record 40 of Set 2 | alakurtti
# Processing Record 41 of Set 2 | avarua
# Processing Record 42 of Set 2 | vila franca do campo
# Processing Record 43 of Set 2 | cherskiy
# Processing Record 44 of Set 2 | qaanaaq
# Processing Record 45 of Set 2 | sorland
# Processing Record 46 of Set 2 | irondequoit
# Processing Record 47 of Set 2 | sola
# Processing Record 48 of Set 2 | chernihiv
# Processing Record 49 of Set 2 | lebu
# Processing Record 50 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 1 of Set 3 | saint-augustin
# Processing Record 2 of Set 3 | chanute
# Processing Record 3 of Set 3 | kerema
# Processing Record 4 of Set 3 | atuona
# Processing Record 5 of Set 3 | russell
# Processing Record 6 of Set 3 | butaritari
# Processing Record 7 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 3 | viedma
# Processing Record 9 of Set 3 | roald
# Processing Record 10 of Set 3 | albany
# Processing Record 11 of Set 3 | bambous virieux
# Processing Record 12 of Set 3 | severo-kurilsk
# Processing Record 13 of Set 3 | yulara
# Processing Record 14 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 15 of Set 3 | kirkcudbright
# Processing Record 16 of Set 3 | mahebourg
# Processing Record 17 of Set 3 | phumi samraong
# City not found. Skipping...
# Processing Record 18 of Set 3 | souillac
# Processing Record 19 of Set 3 | kaeo
# Processing Record 20 of Set 3 | portland
# Processing Record 21 of Set 3 | nizwa
# Processing Record 22 of Set 3 | klaksvik
# Processing Record 23 of Set 3 | kushmurun
# Processing Record 24 of Set 3 | hofn
# Processing Record 25 of Set 3 | metaxades
# Processing Record 26 of Set 3 | uige
# Processing Record 27 of Set 3 | port hardy
# Processing Record 28 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 29 of Set 3 | lasa
# Processing Record 30 of Set 3 | leningradskiy
# Processing Record 31 of Set 3 | dutlwe
# Processing Record 32 of Set 3 | puerto ayora
# Processing Record 33 of Set 3 | rock springs
# Processing Record 34 of Set 3 | muravlenko
# Processing Record 35 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 36 of Set 3 | nanortalik
# Processing Record 37 of Set 3 | upernavik
# Processing Record 38 of Set 3 | salalah
# Processing Record 39 of Set 3 | lorengau
# Processing Record 40 of Set 3 | palmas bellas
# Processing Record 41 of Set 3 | tuktoyaktuk
# Processing Record 42 of Set 3 | rio gallegos
# Processing Record 43 of Set 3 | saskylakh
# Processing Record 44 of Set 3 | general pico
# Processing Record 45 of Set 3 | bambanglipuro
# Processing Record 46 of Set 3 | kodiak
# Processing Record 47 of Set 3 | yumen
# Processing Record 48 of Set 3 | kijang
# Processing Record 49 of Set 3 | puqi
# Processing Record 50 of Set 3 | jaicos
# Processing Record 1 of Set 4 | manokwari
# Processing Record 2 of Set 4 | komsomolskiy
# Processing Record 3 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 4 of Set 4 | whittlesea
# Processing Record 5 of Set 4 | pompeu
# Processing Record 6 of Set 4 | inhambane
# Processing Record 7 of Set 4 | megion
# Processing Record 8 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 9 of Set 4 | ujjain
# Processing Record 10 of Set 4 | beloha
# Processing Record 11 of Set 4 | padang
# Processing Record 12 of Set 4 | fortuna
# Processing Record 13 of Set 4 | benton harbor
# Processing Record 14 of Set 4 | tiksi
# Processing Record 15 of Set 4 | bereda
# Processing Record 16 of Set 4 | ostrovnoy
# Processing Record 17 of Set 4 | saint-philippe
# Processing Record 18 of Set 4 | marawi
# Processing Record 19 of Set 4 | vardo
# Processing Record 20 of Set 4 | pevek
# Processing Record 21 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 22 of Set 4 | frontignan
# Processing Record 23 of Set 4 | tomatlan
# Processing Record 24 of Set 4 | kropotkin
# Processing Record 25 of Set 4 | konigs wusterhausen
# Processing Record 26 of Set 4 | alekseyevsk
# Processing Record 27 of Set 4 | rocha
# Processing Record 28 of Set 4 | manaure
# Processing Record 29 of Set 4 | vao
# Processing Record 30 of Set 4 | akdepe
# Processing Record 31 of Set 4 | lompoc
# Processing Record 32 of Set 4 | paradwip
# City not found. Skipping...
# Processing Record 33 of Set 4 | kabare
# Processing Record 34 of Set 4 | chokurdakh
# Processing Record 35 of Set 4 | karratha
# Processing Record 36 of Set 4 | chapais
# Processing Record 37 of Set 4 | jacksonville
# Processing Record 38 of Set 4 | tura
# Processing Record 39 of Set 4 | chulman
# Processing Record 40 of Set 4 | sao joao da barra
# Processing Record 41 of Set 4 | asyut
# Processing Record 42 of Set 4 | brae
# Processing Record 43 of Set 4 | san patricio
# Processing Record 44 of Set 4 | quilmana
# Processing Record 45 of Set 4 | barrow
# Processing Record 46 of Set 4 | katsuura
# Processing Record 47 of Set 4 | macusani
# Processing Record 48 of Set 4 | ajaccio
# Processing Record 49 of Set 4 | san matias
# Processing Record 50 of Set 4 | mvuma
# Processing Record 1 of Set 5 | scarborough
# Processing Record 2 of Set 5 | narasannapeta
# Processing Record 3 of Set 5 | skelleftea
# Processing Record 4 of Set 5 | eston
# Processing Record 5 of Set 5 | launceston
# Processing Record 6 of Set 5 | anito
# Processing Record 7 of Set 5 | leganes
# Processing Record 8 of Set 5 | narsaq
# Processing Record 9 of Set 5 | coquimbo
# Processing Record 10 of Set 5 | ayagoz
# Processing Record 11 of Set 5 | bethel
# Processing Record 12 of Set 5 | esperance
# Processing Record 13 of Set 5 | pangnirtung
# Processing Record 14 of Set 5 | sooke
# Processing Record 15 of Set 5 | luderitz
# Processing Record 16 of Set 5 | san pedro
# Processing Record 17 of Set 5 | los llanos de aridane
# Processing Record 18 of Set 5 | flin flon
# Processing Record 19 of Set 5 | ucluelet
# Processing Record 20 of Set 5 | cordoba
# Processing Record 21 of Set 5 | qui nhon
# Processing Record 22 of Set 5 | careiro da varzea
# Processing Record 23 of Set 5 | kavaratti
# Processing Record 24 of Set 5 | orgun
# City not found. Skipping...
# Processing Record 25 of Set 5 | zaozerne
# Processing Record 26 of Set 5 | kiama
# Processing Record 27 of Set 5 | roxana
# Processing Record 28 of Set 5 | mao
# Processing Record 29 of Set 5 | the valley
# Processing Record 30 of Set 5 | boguchany
# Processing Record 31 of Set 5 | dakar
# Processing Record 32 of Set 5 | cabo san lucas
# Processing Record 33 of Set 5 | haines junction
# Processing Record 34 of Set 5 | mar del plata
# Processing Record 35 of Set 5 | slave lake
# Processing Record 36 of Set 5 | zyryanka
# Processing Record 37 of Set 5 | bilma
# Processing Record 38 of Set 5 | mana
# Processing Record 39 of Set 5 | saldanha
# Processing Record 40 of Set 5 | port moresby
# Processing Record 41 of Set 5 | buta
# Processing Record 42 of Set 5 | vestmannaeyjar
# Processing Record 43 of Set 5 | nalgonda
# Processing Record 44 of Set 5 | bone
# Processing Record 45 of Set 5 | gat
# Processing Record 46 of Set 5 | grand gaube
# Processing Record 47 of Set 5 | xiongyue
# Processing Record 48 of Set 5 | teahupoo
# Processing Record 49 of Set 5 | xingcheng
# Processing Record 50 of Set 5 | nsanje
# Processing Record 1 of Set 6 | priamurskiy
# Processing Record 2 of Set 6 | filingue
# Processing Record 3 of Set 6 | alotau
# City not found. Skipping...
# Processing Record 4 of Set 6 | provideniya
# Processing Record 5 of Set 6 | itoman
# Processing Record 6 of Set 6 | tokmak
# Processing Record 7 of Set 6 | zhumadian
# Processing Record 8 of Set 6 | beaverlodge
# Processing Record 9 of Set 6 | tigil
# Processing Record 10 of Set 6 | faanui
# Processing Record 11 of Set 6 | at-bashi
# Processing Record 12 of Set 6 | guiuan
# Processing Record 13 of Set 6 | vila velha
# Processing Record 14 of Set 6 | nanakuli
# Processing Record 15 of Set 6 | copiapo
# Processing Record 16 of Set 6 | nemuro
# Processing Record 17 of Set 6 | atbasar
# Processing Record 18 of Set 6 | lerwick
# Processing Record 19 of Set 6 | la ronge
# Processing Record 20 of Set 6 | ribeira grande
# Processing Record 21 of Set 6 | sovetskiy
# Processing Record 22 of Set 6 | teslic
# Processing Record 23 of Set 6 | lagoa
# Processing Record 24 of Set 6 | dikson
# Processing Record 25 of Set 6 | moron
# Processing Record 26 of Set 6 | lloydminster
# Processing Record 27 of Set 6 | nikolskoye
# Processing Record 28 of Set 6 | jambi
# Processing Record 29 of Set 6 | tual
# Processing Record 30 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 31 of Set 6 | praia da vitoria
# Processing Record 32 of Set 6 | karera
# Processing Record 33 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 34 of Set 6 | merauke
# Processing Record 35 of Set 6 | tautira
# Processing Record 36 of Set 6 | linhares
# Processing Record 37 of Set 6 | acapulco
# Processing Record 38 of Set 6 | tamandare
# Processing Record 39 of Set 6 | atlantic city
# Processing Record 40 of Set 6 | bailesti
# Processing Record 41 of Set 6 | taybad
# Processing Record 42 of Set 6 | dabat
# Processing Record 43 of Set 6 | marzuq
# Processing Record 44 of Set 6 | huarmey
# Processing Record 45 of Set 6 | atar
# Processing Record 46 of Set 6 | cananea
# City not found. Skipping...
# Processing Record 47 of Set 6 | mount isa
# Processing Record 48 of Set 6 | grindavik
# Processing Record 49 of Set 6 | pacifica
# Processing Record 50 of Set 6 | kamenka
# Processing Record 1 of Set 7 | okhotsk
# Processing Record 2 of Set 7 | vanimo
# Processing Record 3 of Set 7 | yeppoon
# Processing Record 4 of Set 7 | tulun
# Processing Record 5 of Set 7 | sayhat
# Processing Record 6 of Set 7 | caborca
# Processing Record 7 of Set 7 | bathsheba
# Processing Record 8 of Set 7 | ararangua
# Processing Record 9 of Set 7 | sunbury
# Processing Record 10 of Set 7 | sur
# Processing Record 11 of Set 7 | tilichiki
# Processing Record 12 of Set 7 | port elizabeth
# Processing Record 13 of Set 7 | gushikawa
# Processing Record 14 of Set 7 | alibag
# Processing Record 15 of Set 7 | valparaiso
# Processing Record 16 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 17 of Set 7 | longyearbyen
# Processing Record 18 of Set 7 | la sarre
# Processing Record 19 of Set 7 | macau
# Processing Record 20 of Set 7 | saint george
# Processing Record 21 of Set 7 | alice springs
# Processing Record 22 of Set 7 | mitu
# Processing Record 23 of Set 7 | bukoba
# Processing Record 24 of Set 7 | viransehir
# Processing Record 25 of Set 7 | hervey bay
# Processing Record 26 of Set 7 | cheuskiny
# City not found. Skipping...
# Processing Record 27 of Set 7 | ambilobe
# Processing Record 28 of Set 7 | naze
# Processing Record 29 of Set 7 | belyy yar
# Processing Record 30 of Set 7 | turukhansk
# City not found. Skipping...
# Processing Record 31 of Set 7 | aklavik
# Processing Record 32 of Set 7 | halifax
# Processing Record 33 of Set 7 | talara
# Processing Record 34 of Set 7 | cayenne
# Processing Record 35 of Set 7 | talnakh
# Processing Record 36 of Set 7 | santa ana
# Processing Record 37 of Set 7 | bichura
# Processing Record 38 of Set 7 | george
# Processing Record 39 of Set 7 | bubaque
# Processing Record 40 of Set 7 | srednekolymsk
# Processing Record 41 of Set 7 | bara
# Processing Record 42 of Set 7 | karamay
# City not found. Skipping...
# Processing Record 43 of Set 7 | norman wells
# Processing Record 44 of Set 7 | povenets
# Processing Record 45 of Set 7 | saint-georges
# Processing Record 46 of Set 7 | chodziez
# Processing Record 47 of Set 7 | ayna
# Processing Record 48 of Set 7 | marsa matruh
# Processing Record 49 of Set 7 | sungaipenuh
# Processing Record 50 of Set 7 | carnarvon
# Processing Record 1 of Set 8 | dedza
# Processing Record 2 of Set 8 | umm kaddadah
# Processing Record 3 of Set 8 | pontianak
# Processing Record 4 of Set 8 | kangavar
# Processing Record 5 of Set 8 | ambon
# Processing Record 6 of Set 8 | makakilo city
# Processing Record 7 of Set 8 | arlit
# Processing Record 8 of Set 8 | north platte
# Processing Record 9 of Set 8 | olafsvik
# Processing Record 10 of Set 8 | balabac
# Processing Record 11 of Set 8 | itarema
# Processing Record 12 of Set 8 | nome
# Processing Record 13 of Set 8 | shimanovsk
# Processing Record 14 of Set 8 | tocache
# Processing Record 15 of Set 8 | tara
# Processing Record 16 of Set 8 | goya
# Processing Record 17 of Set 8 | ushtobe
# Processing Record 18 of Set 8 | mariel
# Processing Record 19 of Set 8 | melbu
# Processing Record 20 of Set 8 | wanaka
# Processing Record 21 of Set 8 | talawdi
# City not found. Skipping...
# Processing Record 22 of Set 8 | batagay
# Processing Record 23 of Set 8 | antofagasta
# Processing Record 24 of Set 8 | colesberg
# Processing Record 25 of Set 8 | tarudant
# City not found. Skipping...
# Processing Record 26 of Set 8 | yerbogachen
# Processing Record 27 of Set 8 | broken hill
# Processing Record 28 of Set 8 | shambu
# Processing Record 29 of Set 8 | karlstad
# Processing Record 30 of Set 8 | touros
# Processing Record 31 of Set 8 | visby
# Processing Record 32 of Set 8 | yenagoa
# Processing Record 33 of Set 8 | laa
# Processing Record 34 of Set 8 | shakawe
# Processing Record 35 of Set 8 | bandarbeyla
# Processing Record 36 of Set 8 | gao
# Processing Record 37 of Set 8 | taloqan
# Processing Record 38 of Set 8 | tommot
# Processing Record 39 of Set 8 | teya
# Processing Record 40 of Set 8 | codrington
# Processing Record 41 of Set 8 | laguna
# Processing Record 42 of Set 8 | broome
# Processing Record 43 of Set 8 | guerrero negro
# Processing Record 44 of Set 8 | guiyang
# Processing Record 45 of Set 8 | elizabeth city
# Processing Record 46 of Set 8 | chifeng
# Processing Record 47 of Set 8 | ixtapa
# Processing Record 48 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 49 of Set 8 | faro
# Processing Record 50 of Set 8 | harlev
# Processing Record 1 of Set 9 | lata
# Processing Record 2 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 3 of Set 9 | fairbanks
# Processing Record 4 of Set 9 | marv dasht
# City not found. Skipping...
# Processing Record 5 of Set 9 | cap malheureux
# Processing Record 6 of Set 9 | sangar
# Processing Record 7 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 8 of Set 9 | ust-tsilma
# Processing Record 9 of Set 9 | grootfontein
# Processing Record 10 of Set 9 | port lincoln
# Processing Record 11 of Set 9 | margate
# Processing Record 12 of Set 9 | shepsi
# Processing Record 13 of Set 9 | longonjo
# Processing Record 14 of Set 9 | otjiwarongo
# Processing Record 15 of Set 9 | egvekinot
# Processing Record 16 of Set 9 | diego de almagro
# Processing Record 17 of Set 9 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 18 of Set 9 | rubizhne
# Processing Record 19 of Set 9 | husavik
# Processing Record 20 of Set 9 | ereymentau
# Processing Record 21 of Set 9 | clarksville
# Processing Record 22 of Set 9 | ilhabela
# Processing Record 23 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 24 of Set 9 | matara
# Processing Record 25 of Set 9 | jiazi
# Processing Record 26 of Set 9 | mount gambier
# Processing Record 27 of Set 9 | saint-ambroise
# Processing Record 28 of Set 9 | sambava
# Processing Record 29 of Set 9 | daoukro
# Processing Record 30 of Set 9 | pozo colorado
# Processing Record 31 of Set 9 | aloleng
# Processing Record 32 of Set 9 | djambala
# Processing Record 33 of Set 9 | jiaojiang
# Processing Record 34 of Set 9 | wilmington
# Processing Record 35 of Set 9 | greeneville
# Processing Record 36 of Set 9 | murray bridge
# Processing Record 37 of Set 9 | sistranda
# Processing Record 38 of Set 9 | korla
# Processing Record 39 of Set 9 | ust-koksa
# Processing Record 40 of Set 9 | juifang
# City not found. Skipping...
# Processing Record 41 of Set 9 | santa rosa
# Processing Record 42 of Set 9 | savannah bight
# Processing Record 43 of Set 9 | dourbali
# Processing Record 44 of Set 9 | misawa
# Processing Record 45 of Set 9 | iskateley
# Processing Record 46 of Set 9 | faya
# Processing Record 47 of Set 9 | nantucket
# Processing Record 48 of Set 9 | kalabo
# Processing Record 49 of Set 9 | kirakira
# Processing Record 50 of Set 9 | port blair
# Processing Record 1 of Set 10 | matsanga
# City not found. Skipping...
# Processing Record 2 of Set 10 | jalu
# Processing Record 3 of Set 10 | valuyki
# Processing Record 4 of Set 10 | saint-francois
# Processing Record 5 of Set 10 | koudougou
# Processing Record 6 of Set 10 | uk
# City not found. Skipping...
# Processing Record 7 of Set 10 | kuching
# Processing Record 8 of Set 10 | cecina
# Processing Record 9 of Set 10 | burns lake
# Processing Record 10 of Set 10 | maloy
# Processing Record 11 of Set 10 | lardos
# Processing Record 12 of Set 10 | mecca
# Processing Record 13 of Set 10 | san cristobal
# Processing Record 14 of Set 10 | shimoda
# Processing Record 15 of Set 10 | maarianhamina
# Processing Record 16 of Set 10 | siniscola
# Processing Record 17 of Set 10 | barinas
# Processing Record 18 of Set 10 | teguldet
# Processing Record 19 of Set 10 | quatre cocos
# Processing Record 20 of Set 10 | assiniboia
# Processing Record 21 of Set 10 | caucaia
# Processing Record 22 of Set 10 | rozivka
# Processing Record 23 of Set 10 | tabou
# Processing Record 24 of Set 10 | constitucion
# Processing Record 25 of Set 10 | yar-sale
# Processing Record 26 of Set 10 | kimbe
# Processing Record 27 of Set 10 | sabha
# Processing Record 28 of Set 10 | flinders
# Processing Record 29 of Set 10 | bandar-e anzali
# Processing Record 30 of Set 10 | kautokeino
# Processing Record 31 of Set 10 | voh
# Processing Record 32 of Set 10 | trairi
# Processing Record 33 of Set 10 | svetlyy
# Processing Record 34 of Set 10 | ulety
# Processing Record 35 of Set 10 | half moon bay
# Processing Record 36 of Set 10 | fuerte olimpo
# Processing Record 37 of Set 10 | deshna
# City not found. Skipping...
# Processing Record 38 of Set 10 | ulundi
# Processing Record 39 of Set 10 | yenangyaung
# Processing Record 40 of Set 10 | usinsk
# Processing Record 41 of Set 10 | mahibadhoo
# Processing Record 42 of Set 10 | cangucu
# Processing Record 43 of Set 10 | luganville
# Processing Record 44 of Set 10 | coahuayana
# Processing Record 45 of Set 10 | zyryanovsk
# Processing Record 46 of Set 10 | batyrevo
# Processing Record 47 of Set 10 | bambari
# Processing Record 48 of Set 10 | ouadda
# Processing Record 49 of Set 10 | bakchar
# Processing Record 50 of Set 10 | ossora
# Processing Record 1 of Set 11 | shirokiy
# Processing Record 2 of Set 11 | roma
# Processing Record 3 of Set 11 | vada
# Processing Record 4 of Set 11 | raudeberg
# Processing Record 5 of Set 11 | sao geraldo do araguaia
# Processing Record 6 of Set 11 | omsukchan
# Processing Record 7 of Set 11 | fairhope
# Processing Record 8 of Set 11 | vaitape
# Processing Record 9 of Set 11 | ruthin
# Processing Record 10 of Set 11 | ugoofaaru
# Processing Record 11 of Set 11 | sexsmith
# Processing Record 12 of Set 11 | keetmanshoop
# Processing Record 13 of Set 11 | lodja
# Processing Record 14 of Set 11 | kruisfontein
# Processing Record 15 of Set 11 | walvis bay
# Processing Record 16 of Set 11 | port keats
# Processing Record 17 of Set 11 | rajgarh
# Processing Record 18 of Set 11 | dingle
# Processing Record 19 of Set 11 | bosobolo
# Processing Record 20 of Set 11 | shetpe
# Processing Record 21 of Set 11 | astana
# Processing Record 22 of Set 11 | mattru
# Processing Record 23 of Set 11 | impfondo
# Processing Record 24 of Set 11 | auki
# Processing Record 25 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 26 of Set 11 | olga
# Processing Record 27 of Set 11 | salinas
# Processing Record 28 of Set 11 | borovskoy
# Processing Record 29 of Set 11 | presidencia roque saenz pena
# Processing Record 30 of Set 11 | shahr-e babak
# Processing Record 31 of Set 11 | karasburg
# Processing Record 32 of Set 11 | manggar
# Processing Record 33 of Set 11 | buckeye
# Processing Record 34 of Set 11 | wuda
# Processing Record 35 of Set 11 | krasnoshchekovo
# Processing Record 36 of Set 11 | haibowan
# City not found. Skipping...
# Processing Record 37 of Set 11 | atambua
# Processing Record 38 of Set 11 | soyo
# Processing Record 39 of Set 11 | san rafael
# Processing Record 40 of Set 11 | siuna
# Processing Record 41 of Set 11 | mujiayingzi
# Processing Record 42 of Set 11 | briceni
# Processing Record 43 of Set 11 | laem sing
# Processing Record 44 of Set 11 | urubicha
# Processing Record 45 of Set 11 | tevaitoa
# Processing Record 46 of Set 11 | ponta do sol
# Processing Record 47 of Set 11 | abilene
# Processing Record 48 of Set 11 | dagana
# Processing Record 49 of Set 11 | beringovskiy
# Processing Record 50 of Set 11 | telfs
# Processing Record 1 of Set 12 | san antonio
# Processing Record 2 of Set 12 | alberton
# Processing Record 3 of Set 12 | blythe
# Processing Record 4 of Set 12 | phan rang
# City not found. Skipping...
# Processing Record 5 of Set 12 | maryborough
# Processing Record 6 of Set 12 | vogar
# Processing Record 7 of Set 12 | kaseda
# Processing Record 8 of Set 12 | poum
# Processing Record 9 of Set 12 | waiouru
# Processing Record 10 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 11 of Set 12 | avera
# Processing Record 12 of Set 12 | kutum
# Processing Record 13 of Set 12 | ouro preto
# Processing Record 14 of Set 12 | taft
# Processing Record 15 of Set 12 | florianopolis
# Processing Record 16 of Set 12 | mitsamiouli
# Processing Record 17 of Set 12 | ilulissat
# Processing Record 18 of Set 12 | hameenlinna
# Processing Record 19 of Set 12 | miyoshi
# Processing Record 20 of Set 12 | yithion
# City not found. Skipping...
# Processing Record 21 of Set 12 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 22 of Set 12 | hamilton
# Processing Record 23 of Set 12 | isangel
# Processing Record 24 of Set 12 | griffith
# Processing Record 25 of Set 12 | pergine valsugana
# Processing Record 26 of Set 12 | manolas
# Processing Record 27 of Set 12 | kholtoson
# Processing Record 28 of Set 12 | waipawa
# Processing Record 29 of Set 12 | ladario
# Processing Record 30 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 31 of Set 12 | burica
# City not found. Skipping...
# Processing Record 32 of Set 12 | arya
# Processing Record 33 of Set 12 | korkino
# Processing Record 34 of Set 12 | maltahohe
# Processing Record 35 of Set 12 | piombino
# Processing Record 36 of Set 12 | nicoya
# Processing Record 37 of Set 12 | carahue
# Processing Record 38 of Set 12 | dwarka
# Processing Record 39 of Set 12 | araouane
# Processing Record 40 of Set 12 | gigmoto
# Processing Record 41 of Set 12 | asosa
# Processing Record 42 of Set 12 | anadyr
# Processing Record 43 of Set 12 | victor harbor
# Processing Record 44 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 45 of Set 12 | shiyan
# Processing Record 46 of Set 12 | honningsvag
# Processing Record 47 of Set 12 | mabaruma
# Processing Record 48 of Set 12 | ngukurr
# City not found. Skipping...
# Processing Record 49 of Set 12 | isla mujeres
# Processing Record 50 of Set 12 | gazalkent
# Processing Record 1 of Set 13 | tromso
# Processing Record 2 of Set 13 | menongue
# Processing Record 3 of Set 13 | brcko
# Processing Record 4 of Set 13 | haifa
# Processing Record 5 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 6 of Set 13 | butia
# Processing Record 7 of Set 13 | kadykchan
# City not found. Skipping...
# Processing Record 8 of Set 13 | yinchuan
# Processing Record 9 of Set 13 | lao cai
# Processing Record 10 of Set 13 | safakulevo
# Processing Record 11 of Set 13 | santo antonio do ica
# Processing Record 12 of Set 13 | garoua
# Processing Record 13 of Set 13 | la plata
# Processing Record 14 of Set 13 | byron bay
# Processing Record 15 of Set 13 | saquarema
# Processing Record 16 of Set 13 | japura
# Processing Record 17 of Set 13 | harlingen
# Processing Record 18 of Set 13 | sjovegan
# Processing Record 19 of Set 13 | lebanon
# Processing Record 20 of Set 13 | moba
# Processing Record 21 of Set 13 | tiarei
# Processing Record 22 of Set 13 | saint-pierre
# Processing Record 23 of Set 13 | porto velho
# Processing Record 24 of Set 13 | black forest
# Processing Record 25 of Set 13 | xining
# Processing Record 26 of Set 13 | mudgee
# Processing Record 27 of Set 13 | ferai
# City not found. Skipping...
# Processing Record 28 of Set 13 | sedelnikovo
# City not found. Skipping...
# Processing Record 29 of Set 13 | hasaki
# Processing Record 30 of Set 13 | luau
# Processing Record 31 of Set 13 | bethal
# Processing Record 32 of Set 13 | bataipora
# Processing Record 33 of Set 13 | del rio
# Processing Record 34 of Set 13 | dukat
# Processing Record 35 of Set 13 | mwense
# Processing Record 36 of Set 13 | alofi
# Processing Record 37 of Set 13 | belmonte
# Processing Record 38 of Set 13 | izhma
# Processing Record 39 of Set 13 | imeni zhelyabova
# Processing Record 40 of Set 13 | kamalasai
# Processing Record 41 of Set 13 | upington
# Processing Record 42 of Set 13 | rio grande
# Processing Record 43 of Set 13 | boyolangu
# Processing Record 44 of Set 13 | morehead
# Processing Record 45 of Set 13 | grand baie
# Processing Record 46 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 47 of Set 13 | havoysund
# Processing Record 48 of Set 13 | ostersund
# Processing Record 49 of Set 13 | oussouye
# Processing Record 50 of Set 13 | uglegorsk
# Processing Record 1 of Set 14 | bull savanna
# Processing Record 2 of Set 14 | nogliki
# Processing Record 3 of Set 14 | anori
# Processing Record 4 of Set 14 | mocuba
# Processing Record 5 of Set 14 | manoel urbano
# Processing Record 6 of Set 14 | sinuknipan
# Processing Record 7 of Set 14 | ushumun
# Processing Record 8 of Set 14 | sao filipe
# Processing Record 9 of Set 14 | la maddalena
# Processing Record 10 of Set 14 | nchelenge
# Processing Record 11 of Set 14 | noumea
# Processing Record 12 of Set 14 | izumo
# Processing Record 13 of Set 14 | asilah
# Processing Record 14 of Set 14 | kamloops
# Processing Record 15 of Set 14 | kikwit
# Processing Record 16 of Set 14 | puerto asis
# Processing Record 17 of Set 14 | xai-xai
# Processing Record 18 of Set 14 | nadym
# Processing Record 19 of Set 14 | yanam
# Processing Record 20 of Set 14 | port shepstone
# Processing Record 21 of Set 14 | puri
# Processing Record 22 of Set 14 | sept-iles
# Processing Record 23 of Set 14 | boralday
# Processing Record 24 of Set 14 | aswan
# Processing Record 25 of Set 14 | zyryanskoye
# Processing Record 26 of Set 14 | gangotri
# City not found. Skipping...
# Processing Record 27 of Set 14 | galdar
# Processing Record 28 of Set 14 | moose factory
# Processing Record 29 of Set 14 | ginda
# Processing Record 30 of Set 14 | sumbawanga
# Processing Record 31 of Set 14 | opuwo
# Processing Record 32 of Set 14 | west bay
# Processing Record 33 of Set 14 | shaunavon
# Processing Record 34 of Set 14 | otane
# Processing Record 35 of Set 14 | simoes
# Processing Record 36 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 37 of Set 14 | cumaribo
# City not found. Skipping...
# Processing Record 38 of Set 14 | vitim
# Processing Record 39 of Set 14 | nizhniy kuranakh
# Processing Record 40 of Set 14 | barkly west
# Processing Record 41 of Set 14 | attawapiskat
# City not found. Skipping...
# Processing Record 42 of Set 14 | qaqortoq
# Processing Record 43 of Set 14 | xinzhou
# Processing Record 44 of Set 14 | acari
# Processing Record 45 of Set 14 | tacna
# Processing Record 46 of Set 14 | abu samrah
# Processing Record 47 of Set 14 | roura
# Processing Record 48 of Set 14 | bratsk
# Processing Record 49 of Set 14 | san ignacio
# Processing Record 50 of Set 14 | kirkwall
# Processing Record 1 of Set 15 | hokitika
# Processing Record 2 of Set 15 | umm lajj
# Processing Record 3 of Set 15 | koupela
# Processing Record 4 of Set 15 | pisco
# Processing Record 5 of Set 15 | madimba
# Processing Record 6 of Set 15 | barra
# Processing Record 7 of Set 15 | kabalo
# Processing Record 8 of Set 15 | churapcha
# Processing Record 9 of Set 15 | carbonia
# Processing Record 10 of Set 15 | lensk
# Processing Record 11 of Set 15 | cassilandia
# Processing Record 12 of Set 15 | luangwa
# Processing Record 13 of Set 15 | el rosario
# Processing Record 14 of Set 15 | howard springs
# Processing Record 15 of Set 15 | svetlogorsk
# Processing Record 16 of Set 15 | alta floresta
# Processing Record 17 of Set 15 | rondonopolis
# Processing Record 18 of Set 15 | san carlos de bariloche
# Processing Record 19 of Set 15 | mityana
# Processing Record 20 of Set 15 | tshane
# Processing Record 21 of Set 15 | mahajanga
# Processing Record 22 of Set 15 | abrau-dyurso
# Processing Record 23 of Set 15 | cockburn town
# Processing Record 24 of Set 15 | mindupok
# Processing Record 25 of Set 15 | manitouwadge
# Processing Record 26 of Set 15 | wanning
# Processing Record 27 of Set 15 | santo amaro da imperatriz
# Processing Record 28 of Set 15 | chicama
# Processing Record 29 of Set 15 | farkhor
# Processing Record 30 of Set 15 | berlevag
# Processing Record 31 of Set 15 | andros town
# Processing Record 32 of Set 15 | turbat
# Processing Record 33 of Set 15 | bagado
# Processing Record 34 of Set 15 | makat
# Processing Record 35 of Set 15 | liwale
# Processing Record 36 of Set 15 | mogadishu
# Processing Record 37 of Set 15 | dalfsen
# Processing Record 38 of Set 15 | talcahuano
# Processing Record 39 of Set 15 | plano
# Processing Record 40 of Set 15 | akyab
# Processing Record 41 of Set 15 | acarigua
# Processing Record 42 of Set 15 | nago
# Processing Record 43 of Set 15 | tifton
# Processing Record 44 of Set 15 | severnoye
# Processing Record 45 of Set 15 | puerto colombia
# Processing Record 46 of Set 15 | tubmanburg
# Processing Record 47 of Set 15 | morden
# Processing Record 48 of Set 15 | mantua
# Processing Record 49 of Set 15 | tabialan
# City not found. Skipping...
# Processing Record 50 of Set 15 | kedrovyy
# Processing Record 1 of Set 16 | unjha
# Processing Record 2 of Set 16 | santa fe do sul
# Processing Record 3 of Set 16 | nyurba
# Processing Record 4 of Set 16 | havelock
# Processing Record 5 of Set 16 | marabba
# Processing Record 6 of Set 16 | malakal
# Processing Record 7 of Set 16 | karaul
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Busselton      AU -33.6500  115.3333     59.18        70          86
# 1     Cape Town      ZA -33.9258   18.4232     57.88        81          40
# 2         Vaini      TO -21.2000 -175.2000     75.36       100          75
# 3          Lamu      KE  -2.2717   40.9020     77.22        76          45
# 4       Maumere      ID  -8.6199  122.2111     78.51        80         100
# 5      Chumikan      RU  54.7183  135.3150     38.84       100         100
# 6  Port-Cartier      CA  50.0334  -66.8654     55.62        67         100
# 7         Bluff      NZ -46.6000  168.3333     45.81        83         100
# 8       Ardakan      IR  32.3100   54.0175     88.77        14           0
# 9        Castro      BR -24.7911  -50.0119     59.11        57           0
#
#    Wind Speed Current Description
# 0       20.40     overcast clouds
# 1        5.75          light rain
# 2        9.22       broken clouds
# 3       16.75    scattered clouds
# 4        6.78     overcast clouds
# 5        1.88          light rain
# 6       18.19     overcast clouds
# 7       12.41     overcast clouds
# 8        2.08           clear sky
# 9        3.96           clear sky

# %%
#format the dataframe
city_data_df["Lat"] = city_data_df["Lat"].map("{:.2f}".format)
city_data_df["Lng"] = city_data_df["Lng"].map("{:.2f}".format)
city_data_df.head()
# Out:
#         City Country     Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0  Busselton      AU  -33.65   115.33     59.18        70          86
# 1  Cape Town      ZA  -33.93    18.42     57.88        81          40
# 2      Vaini      TO  -21.20  -175.20     75.36       100          75
# 3       Lamu      KE   -2.27    40.90     77.22        76          45
# 4    Maumere      ID   -8.62   122.21     78.51        80         100
#
#    Wind Speed Current Description
# 0       20.40     overcast clouds
# 1        5.75          light rain
# 2        9.22       broken clouds
# 3       16.75    scattered clouds
# 4        6.78     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
